# %%
from IPython.display import SVG

# %%
display(SVG("/home/salmon/workspace/output/tokamak_prev.svg"))

# %%
SVG(open("/home/salmon/workspace/output/tokamak_post.svg").read())

# %%
from fytok.utils.load_scenario import load_scenario
# Out:
# 2023-06-16 14:34:53,240 INFO [spdm] : Set mapping path: /home/salmon/workspace/fytok/python/fytok/_mapping

# %%
scenario = load_scenario("/home/salmon/workspace/data/15MA inductive - burn")
# Out:
# 2023-06-16 14:34:59,895 INFO [spdm] : Load scenario/profiles from /home/salmon/workspace/data/15MA inductive - burn/15MA Inductive at burn-ASTRA.xls
# 2023-06-16 14:35:00,007 INFO [spdm] : Load module spdm.plugins.data.PluginGEQdsk from /home/salmon/workspace/SpDB/python/spdm/plugins/data/PluginGEQdsk.py
# 2023-06-16 14:35:00,012 DEBUG [spdm] /home/salmon/workspace/SpDB/python/spdm/plugins/data/PluginGEQdsk.py:329:__init__: Open File URITuple(protocol='local', authority='', path=PosixPath('/home/salmon/workspace/data/15MA inductive - burn/Increased domain R-Z/Medium resolution - 129x257/g900003.00230_ITER_15MA_eqdsk16VVMR.txt'), query=None, fragment='', format='', schema='') mode=Mode.read
# 2023-06-16 14:35:00,038 INFO [spdm] : Load scenario/equilibrium from /home/salmon/workspace/data/15MA inductive - burn/Increased domain R-Z/Medium resolution - 129x257/g900003.00230_ITER_15MA_eqdsk16VVMR.txt

# %%
psirz=scenario["equilibrium"]["time_slice"][0]["profiles_2d"][0]["psi"]
