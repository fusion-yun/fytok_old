# %%
import numpy as np
from spdm.utils.logger import logger
from fytok.modules.Equilibrium import Equilibrium

# %%
eq = Equilibrium({
    "time_slice":[{
        
    }]
})
# Out:
# 2023-08-30 08:42:12,956 INFO [spdm]: Load module spdm.plugins.data.PluginGEQdsk from /home/salmon/workspace/SpDB/python/spdm/plugins/data/PluginGEQdsk.py
# 2023-08-30 08:42:12,958 DEBUG [spdm] /home/salmon/workspace/SpDB/python/spdm/plugins/data/PluginGEQdsk.py:329:__init__: Open File URITuple(protocol='file', authority='', path='/home/salmon/workspace/gacode/neo/tools/input/profile_data/g141459.03890', query=None, fragment=None, format='GEQdsk', schema=None) mode=Mode.read
# 2023-08-30 08:42:13,149 INFO [spdm]: Load module fytok.plugins.equilibrium.eq_analyze from /home/salmon/workspace/fytok/python/fytok/plugins/equilibrium/eq_analyze.py

# %%
display(eq)
# Out:
# 2023-08-30 08:40:26,962 INFO [spdm]: Load module spdm.view.MatplotlibView from /home/salmon/workspace/SpDB/python/spdm/view/MatplotlibView.py
# 2023-08-30 08:40:26,993 INFO [spdm]: Load module spdm.mesh.RectangularMesh from /home/salmon/workspace/SpDB/python/spdm/mesh/RectangularMesh.py

# %%
pf_active.coil[0].current(1.2345)
