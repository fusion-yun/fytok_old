# %%
from fytok.Tokamak import Tokamak

tok = Tokamak(f"EAST+MDSplus:///home/salmon/workspace/fytok_data/mdsplus/~t/?enable=efit_east&shot=70754")

tok.refresh(time=5.0)
# Out:
# 2023-10-13 15:00:40,126 [   fytok]     INFO:
# #######################################################################################################################
#
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
# Copyright (c) 2021-present Zhi YU (Institute of Plasma Physics Chinese Academy of Sciences)
# URL         : https://gitee.com/openfusion/fytok_tutorial
#
# version = 0.2.0rc0
# #######################################################################################################################
#
# 2023-10-13 15:00:40,146 [   fytok]     INFO: Mapping path    	: [PosixPath('/home/salmon/workspace/fytok/python/fytok/_mapping'), PosixPath('/home/salmon/workspace/fytok_ext/python/fytok/_mapping')]
# 2023-10-13 15:00:40,294 [   fytok]     INFO: Ontology      	: imas/3
# 2023-10-13 15:00:40,372 [   fytok]     INFO: IMAS version  	: 3.38.1-dirty
# 2023-10-13 15:00:40,553 [   fytok]     INFO: Load module   	:'eq_analyze'  VERSION='0.0.1' COPYRIGHT='Zhi YU @ASIPP (2022 - Now)'

# %%
display(tok)
# Out:
# 2023-10-13 15:00:40,671 [   fytok]    DEBUG: /home/salmon/workspace/fytok/../fytok/python/fytok/Tokamak.py:229:__geometry__: Can not get TF.__geometry__ !

# %%
tok.equilibrium

# %%
tok.wall

# %%
tok.pf_active

# %%
tok.magnetics

# %%
from spdm.view import View as sp_view

fig=sp_view.display(tok.__geometry__(view="top"))
# Out:
# 2023-10-13 15:00:42,110 [   fytok]    DEBUG: /home/salmon/workspace/fytok/../fytok/python/fytok/Tokamak.py:229:__geometry__: Can not get TF.__geometry__ !
