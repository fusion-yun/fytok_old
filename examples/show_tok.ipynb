# %%
from fytok.Tokamak import Tokamak

tok = Tokamak(f"EAST+MDSplus:///home/salmon/workspace/fytok_data/mdsplus/~t/?enable=efit_east&shot=70754")

tok.refresh(time=5.0)
# Out:
# 2023-10-16 11:59:18,170 [   fytok]     INFO: Ontology      	: imas/3
# 2023-10-16 11:59:18,257 [   fytok]     INFO: IMAS DD version  	: v3_38_1_dirty
# 2023-10-16 11:59:18,259 [   fytok]     INFO:
# #######################################################################################################################
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
#
#  Copyright (c) 2021-present Zhi YU (Institute of Plasma Physics Chinese Academy of Sciences)
#
#  version = 0.2.1 ( extension=0.1.dev106+g2fdd375.d20231016, imas_version=v3_38_1_dirty )
#
#  url: https://gitee.com/openfusion/fytok_tutorial
#       https://github.com/fusion-yun/fytok_tutorial
#
#  Run by Salmon on Surface at 2023-10-16T11:59:18.259606
#
# #######################################################################################################################
#
# 2023-10-16 11:59:18,263 [   fytok]     INFO: Mapping path    	: [PosixPath('/home/salmon/workspace/fytok/python/fytok/_mapping'), PosixPath('/home/salmon/workspace/fytok_ext/python/fytok/_mapping')]
# 2023-10-16 11:59:18,593 [   fytok]     INFO: Load module   	:'eq_analyze'  VERSION='0.0.1' COPYRIGHT='Zhi YU @ASIPP (2022 - Now)'

# %%
display(tok)
# Out:
# 2023-10-16 11:59:18,728 [   fytok]    DEBUG: /home/salmon/workspace/fytok/python/fytok/Tokamak.py:229:__geometry__: Can not get TF.__geometry__ !

# %%
tok.equilibrium

# %%
tok.wall

# %%
tok.pf_active

# %%
tok.magnetics

# %%
from spdm.view import View as sp_view

fig=sp_view.display(tok.__geometry__(view="top"))
# Out:
# 2023-10-16 11:59:20,210 [   fytok]    DEBUG: /home/salmon/workspace/fytok/python/fytok/Tokamak.py:229:__geometry__: Can not get TF.__geometry__ !

# %%
software/f/fytok/0.2.1/lib/python3.10/site_pacakges/fytok
software/f/fytok_ext/0.2.1/lib/python3.10/site_pacakges/fytok
