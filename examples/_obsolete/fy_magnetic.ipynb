# %%
import sys
import collections
import matplotlib.pyplot as plt
import numpy as np
from scipy import special
import math

sys.path.append("/home/salmon/workspace/freegs/")
sys.path.append("/home/salmon/workspace/fytok/python")
sys.path.append("/home/salmon/workspace/SpDev/SpDB/python")

from spdm.utils.logger import logger
from spdm.data.Collection import Collection
from fytok.Tokamak import Tokamak
from spdm.utils.logger import logger
from spdm.data.Profile import Profile
from spdm.data.Collection import Collection
from spdm.data.AttributeTree import _next_

# %%
entry=Collection("EAST+mdsplus:///home/salmon/public_data/~t/?tree_name=efit_east").open(shot=55555, time_slice=20).entry
tok = Tokamak(entry)
# Out:
# 2021-01-07 15:07:34,871 INFO [spdm] : Open MDSplusCollection :
#  {'schema': 'mdsplus', 'authority': '', 'path': '/home/salmon/public_data/~t/', 'query': {'tree_name': 'efit_east'}, 'fragment': None}
# 2021-01-07 15:07:34,874 INFO [spdm] : Open EASTCollection :
#  {'authority': '',
#  'fragment': None,
#  'path': '/home/salmon/public_data/~t/',
#  'query': {'tree_name': 'efit_east'},
#  'schema': 'EAST+mdsplus'}
# 2021-01-07 15:07:34,875 INFO [spdm] : Opend MDSTree: tree_name=efit_east shot=55555 mode="ReadOnly" path='/home/salmon/public_data/~t/'
# 2021-01-07 15:07:34,878 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/config.xml
# 2021-01-07 15:07:34,880 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/magnetics.xml
# 2021-01-07 15:07:34,882 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/wall.xml
# 2021-01-07 15:07:34,883 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/pf_active.xml
# 2021-01-07 15:07:34,885 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/config.xml
# 2021-01-07 15:07:34,887 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/equilibrium.xml
# 2021-01-07 15:07:34,888 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/magnetics.xml
# 2021-01-07 15:07:34,890 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/pf_active.xml
# 2021-01-07 15:07:34,891 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/python/spdm/data/file/XML.py:70:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/tf.xml
# 2021-01-07 15:07:34,896 INFO [spdm] : Load 'Equilibrium' module FreeGS!

# %%
control_line=[
    
    ((1.99,0    ),    (2.40, 0     )   ),     # isoflux01
    ((1.93, 0.15),    (2.24, 0.52  )  ),   # isoflux03
    ((1.72, 0.24),    (1.35, 0.45  )  ),   # isoflux04
    ((1.66,0    ),    (1.35, 0     )   ),     # isoflux06
    ((1.72,-0.24) ,   (1.35, -0.45 )   ),    # isoflux08
    ((1.93,-0.15),    (2.24, -0.52 )   ),   # isoflux09
    ]                          

r=0.5
pts=[ ((1.0-r)*b[0] + r*e[0], (1.0-r)*b[1] + r*e[1] )  for b,e in control_line  ]

isoflux=[
    (*pts[0],*pts[3]),
    (*pts[1],*pts[4]),
    (*pts[2],*pts[5]),
    
] 
print(isoflux)

for r0,z0,r1,z1 in isoflux:
    plt.plot([r0,r1],[z0,z1])

tok.equilibrium.update(
    constraints={
        # "psivals": psivals,
        # "xpoints": xpoints,
        "isoflux": isoflux
    })

tok.wall.plot()
tok.pf_active.plot()
tok.equilibrium.plot(oxpoints=False,boundary=False)
plt.gca().set_aspect('equal')
# Out:
# [(2.195, 0.0, 1.505, 0.0), (2.085, 0.335, 1.5350000000000001, -0.345), (1.5350000000000001, 0.345, 2.085, -0.335)]
# 2021-01-07 15:07:41,398 INFO [spdm] : Create Equilibrium
# 2021-01-07 15:07:43,083 DEBUG [spdm] /home/salmon/workspace/fytok/python/fytok/plugins/modules/transport/equilibrium/PluginFreeGS.py:80:update: Create Profile: Constrain poloidal Beta and plasma current
#                      Betap                      =0.23003898995193187 [-],
#                      Plasma current Ip          =332862.90486653644 [Amps],
#                      fvac                       =4.018389737368528 [T.m]

# %%
# lfcs_r = tok.equilibrium.boundary.outline.r
# lfcs_z = tok.equilibrium.boundary.outline.z
# psivals = [(R, Z, 0.0) for R, Z in zip(lfcs_r, lfcs_z)]
# xpoints = [[p.r, p.z] for p in tok.equilibrium.boundary.x_point]
# ir_min = np.argmin(lfcs_r)
# ir_max = np.argmax(lfcs_r)
# iz_min = np.argmin(lfcs_z)
# iz_max = np.argmax(lfcs_z)
# isoflux = [(lfcs_r[ir_min], lfcs_z[ir_min], lfcs_r[ir_max], lfcs_z[ir_max]),
#            (lfcs_r[iz_min], lfcs_z[iz_min], lfcs_r[iz_max], lfcs_z[iz_max])]  # (R1,Z1, R2,Z2) pair of locations
# xpoints[0][0] += 0.1
# xpoints[0][1] -= 0.1
# xpoints[1][0] += 0.1
# xpoints[1][1] += 0.1
# tok.equilibrium.update(
#     constraints={
#         # "psivals": psivals,
#         "xpoints": xpoints,
#         "isoflux": isoflux
#     })

# %%
db = Collection("east+mdsplus:///home/salmon/public_data/~t/",default_tree_name="efit_east")
entry = db.open(shot=55555).entry
# Out:
# 2020-12-12 09:24:06,884 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:77:sp_find_module: Can not find module spdm.data.plugins.Plugineast#eastCollection
# 2020-12-12 09:24:06,885 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:77:sp_find_module: Can not find module spdm.data.plugins.PluginEast#EastCollection
# 2020-12-12 09:24:06,901 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:75:sp_find_module: Found module : spdm.data.plugins.PluginEAST#EASTCollection
# 2020-12-12 09:24:06,903 INFO [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Plugin.py:88:find_plugin: Load Plugin: EASTCollection
# 2020-12-12 09:24:07,001 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:75:sp_find_module: Found module : spdm.data.plugins.PluginMDSplus#MDSplusCollection
# 2020-12-12 09:24:07,002 INFO [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Plugin.py:88:find_plugin: Load Plugin: MDSplusCollection
# 2020-12-12 09:24:07,003 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Collection.py:63:__init__: Open MDSplusCollection :  mdsplus:///home/salmon/public_data/~t/
# 2020-12-12 09:24:07,004 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Collection.py:63:__init__: Open EASTCollection :  east+mdsplus:///home/salmon/public_data/~t/
# 2020-12-12 09:24:07,047 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:75:sp_find_module: Found module : spdm.data.plugins.PluginXML#XMLDocument
# 2020-12-12 09:24:07,048 INFO [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Plugin.py:88:find_plugin: Load Plugin: XMLDocument
# 2020-12-12 09:24:07,054 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/config.xml
# 2020-12-12 09:24:07,058 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/magnetics.xml
# 2020-12-12 09:24:07,061 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/wall.xml
# 2020-12-12 09:24:07,065 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/pf_active.xml
# 2020-12-12 09:24:07,067 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/static/tf.xml
# 2020-12-12 09:24:07,068 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/config.xml
# 2020-12-12 09:24:07,070 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/equilibrium.xml
# 2020-12-12 09:24:07,073 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/magnetics.xml
# 2020-12-12 09:24:07,075 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/pf_active.xml
# 2020-12-12 09:24:07,076 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginXML.py:69:load_xml: Loading XML file from /home/salmon/workspace/fytok/devices/EAST/imas/3/dynamic/tf.xml
# 2020-12-12 09:24:07,082 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Document.py:29:__init__: Opend XMLDocument fid=None
# 2020-12-12 09:24:07,083 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Document.py:29:__init__: Opend MDSplusDocument fid=55555
# 2020-12-12 09:24:07,084 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/Document.py:29:__init__: Opend MappingDocument fid=55555

# %%
vessel_inner_points= np.array([entry.wall.description_2d.vessel.annular.outline_inner.r.__value__(),    
                                          entry.wall.description_2d.vessel.annular.outline_inner.z.__value__()]).transpose([1,0]) 

vessel_outer_points= np.array([entry.wall.description_2d.vessel.annular.outline_outer.r.__value__(),    
                                          entry.wall.description_2d.vessel.annular.outline_outer.z.__value__()]).transpose([1,0])  

limiter_points =  np.array([entry.wall.description_2d[0].limiter.unit[0].outline.r.__value__(),
                                 entry.wall.description_2d[0].limiter.unit[0].outline.z.__value__()]).transpose([1,0]) 
isoflux=[
    (1.93, 0.15,    2.24, 0.52    ),   # isoflux03
    (1.99,0    ,    2.40, 0        ),     # isoflux01
    (1.93,-0.15,    2.24, -0.52    ),   # isoflux09
    (1.72, 0.24,    1.35, 0.45    ),   # isoflux04
    (1.66,0    ,    1.35, 0        ),     # isoflux06
    (1.72,-0.24 ,   1.35, -0.45    ),    # isoflux08

    ]

# %%
sys.path.append("/home/salmon/workspace/freegs/")
import freegs
from freegs.machine import Machine,Wall
import freegs.equilibrium as equilibrium
import freegs.jtor as jtor
import freegs.picard as picard
import freegs.boundary as boundary
from  freegs.coil import Coil

# %%
itime=40000
coils = []
for coil in entry.pf_active.coil:
    rect = coil.element[0].geometry.rectangle.__value__()
    coils.append((str(coil.name), Coil(
    rect.r+rect.width/2, rect.z+rect.height/2,
    current= coil.current.data.__value__()[itime] ,
    turns=int(coil.element[0].turns_with_sign),
    # control=True
    )))

wall = Wall(entry.wall.description_2d[0].limiter.unit[0].outline.r.__value__(),
            entry.wall.description_2d[0].limiter.unit[0].outline.z.__value__())

Rdim=entry.equilibrium.time_slice[10].profiles_2d.grid.dim1
Zdim=entry.equilibrium.time_slice[10].profiles_2d.grid.dim2

lfcs_r=entry.equilibrium.time_slice[10].boundary.outline.r
lfcs_z=entry.equilibrium.time_slice[10].boundary.outline.z

EASTTokamak = Machine(coils, wall)



rmin=min(Rdim)
rmax=max(Rdim)
zmin=min(Zdim)
zmax=max(Zdim)

eq = equilibrium.Equilibrium(tokamak=EASTTokamak,
                                Rmin=rmin, Rmax=rmax,
                                Zmin=zmin, Zmax=zmax,
                                nx=129, ny=129,
                                boundary=boundary.freeBoundaryHagenow)
# Out:
# 2020-12-04 13:06:28,098 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/data/plugins/PluginMDSplus.py:59:open_mdstree: Opend MDSTree: tree_name=pcs_east shot=55555 mode="NORMAL"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9f69377eb55d> in <module>
#      13             entry.wall.description_2d[0].limiter.unit[0].outline.z.__value__())
#      14
# ---> 15 Rdim=entry.equilibrium.time_slice[10].profiles_2d.grid.dim1.__value__()
#      16 Zdim=entry.equilibrium.time_slice[10].profiles_2d.grid.dim2.__value__()
#      17
#
# ~/workspace/SpDev/SpDB/spdm/util/LazyProxy.py in __value__(self)
#     250
#     251     def __value__(self):
# --> 252         res = self.__real_value__()
#     253         if isinstance(res, collections.abc.Mapping):
#     254             return LazyProxy(res)
#
# ~/workspace/SpDev/SpDB/spdm/util/LazyProxy.py in __real_value__(self)
#     247         path = object.__getattribute__(self, "__path__")
#     248         handler = object.__getattribute__(self, "__handler__")
# --> 249         return handler.get_value(obj, path)
#     250
#     251     def __value__(self):
#
# ~/workspace/SpDev/SpDB/spdm/data/Node.py in get_value(self, path, *args, **kwargs)
#     109
#     110     def get_value(self,  path, *args, **kwargs):
# --> 111         return self.get(path, *args, **kwargs)
#     112
#     113     def delete(self, path, *args, **kwargs):
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in get(self, path, is_raw_path, *args, **kwargs)
#      60     def get(self,  path, *args,  is_raw_path=False,  **kwargs):
#      61         if not is_raw_path:
# ---> 62             res = PathTraverser(path).apply(lambda p: self.get(p,  is_raw_path=True, **kwargs))
#      63         else:
#      64             item = self._mapping.get_value(path, *args, **kwargs)
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in apply(self, visitor)
#      50
#      51     def apply(self, visitor):
# ---> 52         res = self.traverse(visitor, [], 0)
#      53         return res[0] if self.is_multiple else res
#      54
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpDB/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      23         res = None
#      24         if idx >= len(self._path):
# ---> 25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
#      27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in <lambda>(p)
#      60     def get(self,  path, *args,  is_raw_path=False,  **kwargs):
#      61         if not is_raw_path:
# ---> 62             res = PathTraverser(path).apply(lambda p: self.get(p,  is_raw_path=True, **kwargs))
#      63         else:
#      64             item = self._mapping.get_value(path, *args, **kwargs)
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in get(self, path, is_raw_path, *args, **kwargs)
#      63         else:
#      64             item = self._mapping.get_value(path, *args, **kwargs)
# ---> 65             res = self._fetch(item)
#      66         return res
#      67
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in _fetch(self, item, *args, **kwargs)
#      49             if self._holder is None:
#      50                 raise RuntimeError()
# ---> 51             res = self._holder.get(item["{http://hpc.ipp.ac.cn/SpDB}data"], *args, **kwargs)
#      52         else:
#      53             res = {k: self._fetch(v) for k, v in item.items()}
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMDSplus.py in get(self, path, projection, *args, **kwargs)
#      28         if isinstance(path, str) and len(path) > 0:
#      29             try:
# ---> 30                 res = self.holder[tree_name].tdiExecute(path)
#      31             except mds.mdsExceptions.TdiException as error:
#      32                 raise RuntimeError(f"MDSplus TDI error [{path}]! {error}")
#
# ~/workspace/SpDev/SpDB/spdm/util/dict_util.py in __missing__(self, k)
#       6
#       7     def __missing__(self, k):
# ----> 8         v = self._factory(k)
#       9         self.__setitem__(k,  v)
#      10         return v
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMDSplus.py in <lambda>(t, s, m)
#      81         mds_mode = MDSplusDocument.MDS_MODE.get(mode, "NORMAL")
#      82
# ---> 83         self._trees = DefaultDict(lambda t, s=fid, m=mds_mode: open_mdstree(t, s, mode=m))
#      84
#      85         if tree_name is not None:
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMDSplus.py in open_mdstree(tree_name, shot, mode)
#      54 def open_mdstree(tree_name, shot,  mode="NORMAL"):
#      55     if tree_name is None:
# ---> 56         raise ValueError(f"Treename is empty!")
#      57     try:
#      58         shot = int(shot)
#
# ValueError: Treename is empty!

# %%
profiles = jtor.ConstrainPaxisIp(1e3,  # Plasma pressure on axis [Pascals]
                            1e6,  # Plasma current [Amps]
                            1.0)  # fvac = R*Bt

psivals = [ (R, Z, 0.0) for R, Z in zip(lfcs_r,lfcs_z)]
# psivals = [ (R, Z, 0.0) for R, Z in zip(entry.equilibrium.time_slice[10].boundary.outline.r.__value__(), 
#             entry.equilibrium.time_slice[10].boundary.outline.z.__value__()) ]


constrain = freegs.control.constrain(psivals=psivals)
freegs.solve(eq, profiles,constrain) 
ax=eq.plot(show=False)

# %%
constrain=freegs.control.constrain(
    isoflux=[    
    ( 2.24, 0.52 ,  2.24,   -0.52     ),    
    ( 1.93, 0.15,   1.93,   -0.15,    ),    
    ( 1.99, 0 ,     1.66,   0),
  
   ],
    xpoints=[(1.63,-0.83),(1.63,0.83)]
)

freegs.solve(eq, profiles, constrain,maxits=200) 

eq.plot(show=False)
# Out:
# <AxesSubplot:xlabel='Major radius [m]', ylabel='Height [m]'>

# %%
psinorm=np.linspace(1.0/128,1,128)
plt.plot(psinorm,eq.fpol(psinorm))

# %%
fg=plt.figure()

plt.gca().add_patch(plt.Polygon(limiter_points, fill=False,closed=True))
plt.gca().add_patch(plt.Polygon(vessel_outer_points , fill=False,closed=True))
plt.gca().add_patch(plt.Polygon(vessel_inner_points , fill=False,closed=True))

plt.gca().add_patch(plt.Polygon(np.array([lfcs_r,lfcs_z]).transpose([1,0]) , fill=False,closed=True,linestyle="dashed",color="red"))

for r0,z0,r1,z1 in isoflux:
    plt.plot([r0,r1],[z0,z1])

for coil  in entry.pf_active.coil:
    rect=coil.element[0].geometry.rectangle.__value__() 
    plt.gca().add_patch(plt.Rectangle((rect.r-rect.width/2.0, rect.z-rect.height/2.0),float( rect.width), float(rect.height), fill=False))
 

plt.contour(
    entry.equilibrium.time_slice[10].profiles_2d.grid.dim1.__value__(),
    entry.equilibrium.time_slice[10].profiles_2d.grid.dim2.__value__(),
    entry.equilibrium.time_slice[10].profiles_2d.psi.__value__(),
    linewidths=0.5,cmap="gray")

plt.contour(eq.R,eq.Z,eq.psi(),levels=50,linewidths=0.5)


plt.axis('scaled')
plt.show()

# %%
psi_norm=[*np.linspace(0.1,0.9,9),0.99]
psi=eq.psi()
C=plt.contour(eq.R,eq.Z,(psi-eq.psi_axis)/(eq.psi_bndry-eq.psi_axis),
levels=psi_norm)
sep=eq.separatrix(ntheta=128)
plt.plot(sep[:,0],sep[:,1])
plt.plot(eq.R[39,20],eq.Z[30,20],"rx")

# %%
for ii, seg in enumerate(C.allsegs[-1]):
    plt.plot(seg[:,0], seg[:,1], '.-', label=ii)
    plt.legend()

# %%
from scipy import interpolate

# %%
f=interpolate.RectBivariateSpline(eq.R[:,0], eq.Z[0,:], eq.psi())

# %%
Br=-f(eq.R,eq.Z,dy=1,grid=False)/eq.R
Bz= f(eq.R,eq.Z,dx=1,grid=False)/eq.R
Bp2=Br**2+Bz**2
Bp=np.sqrt(Bp2)

# %%
dbp2=interpolate.RectBivariateSpline(eq.R[:,0], eq.Z[0,:], Bp2)

# %%
plt.contour(eq.R,eq.Z, Bp2)

# %%
np.linspace(-1,1,5)
# Out:
# array([-1. , -0.5,  0. ,  0.5,  1. ])

# %%
from scipy.ndimage.filters import maximum_filter,minimum_filter
from scipy.ndimage.morphology import generate_binary_structure, binary_erosion




def detect_peaks(image):
    """
    Takes an image and detect the peaks usingthe local maximum filter.
    Returns a boolean mask of the peaks (i.e. 1 when
    the pixel's value is the neighborhood maximum, 0 otherwise)
    """

    # define an 8-connected neighborhood
    neighborhood = generate_binary_structure(2,2)

    #apply the local maximum filter; all pixel of maximal value 
    #in their neighborhood are set to 1
    local_max = minimum_filter(image, footprint=neighborhood)==image
    #local_max is a mask that contains the peaks we are 
    #looking for, but also the background.
    #In order to isolate the peaks we must remove the background from the mask.

    #we create the mask of the background
    background = (image==0)

    #a little technicality: we must erode the background in order to 
    #successfully subtract it form local_max, otherwise a line will 
    #appear along the background border (artifact of the local maximum filter)
    eroded_background = binary_erosion(background, structure=neighborhood, border_value=1)

    #we obtain the final mask, containing only peaks, 
    #by removing the background from the local_max mask (xor operation)
    detected_peaks = local_max ^ eroded_background

    return detected_peaks

span=5

ridx,zidx =np.where( detect_peaks( Bp2[span:-span,span:-span]))

# %%
r= [  eq.R[ridx[i]+span,zidx[i]+span]   for i  in range(len(ridx)) ]
z= [  eq.Z[ridx[i]+span,zidx[i]+span]   for i  in range(len(ridx)) ]

plt.plot(r,z,"r.", linewidth=0.2 ,markersize=0.2)
plt.contour(eq.R,eq.Z, psi, levels=[1.01*eq.psi_bndry,eq.psi_axis], linewidths=0.2)
plt.contour(eq.R,eq.Z,Bp ,levels=np.linspace(0,Bp.max(),50), linewidths=0.2)
# plt.contour(eq.R,eq.Z, f(eq.R,eq.Z,dx=2,dy=1,grid=False)/eq.R,levels=np.linspace(-10,10,20))
plt.gca().axis("scaled")
# Out:
# (1.2, 2.6, -1.2, 1.2)

# %%
from sympy import Point ,Polygon

# %%
limiter_polygon=Polygon(*map(Point,limiter_points))

# %%
limiter_polygon.encloses_point (Point(r[0],z[0]))
# Out:
# True

# %%
x_idx, y_idx = np.where( detect_peaks( Bp2[span:-span,span:-span]))
p_idx=np.array([x_idx, y_idx]).transpose(1, 0)
p_xy=np.array([ [eq.R[idx[0],idx[1]],eq.Z[idx[0],idx[1]]] for idx in p_idx])

# %%
plt.plot(p_xy[:,0],p_xy[:,1],"rx")

# %%
p_xy.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-238-17557c87f4ae> in <module>
# ----> 1 p_xy.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
for idx,p in enumerate(p_xy):
    print((idx,p))
# Out:
# (0, array([ 1.571875, -0.91875 ]))
# (1, array([1.571875, 0.73125 ]))
# (2, array([ 1.76875, -0.09375]))
# (3, array([ 2.359375, -0.6375  ]))
# (4, array([2.359375, 0.5625  ]))
